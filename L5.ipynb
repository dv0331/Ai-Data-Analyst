# %% [markdown]
# # L5: Data Analyst Agent 🤓

# %% [markdown]
# <div style="background-color:#fff6ff; padding:13px; border-width:3px; border-color:#efe6ef; border-style:solid; border-radius:6px">
# <p> 💻 &nbsp; <b>Access <code>requirements.txt</code> , notebooks and other files:</b> 1) click on the <em>"File"</em> option on the top menu of the notebook and then 2) click on <em>"Open"</em>.
#
# <p> ⬇ &nbsp; <b>Download Notebooks:</b> 1) click on the <em>"File"</em> option on the top menu of the notebook and then 2) click on <em>"Download as"</em> and select <em>"Notebook (.ipynb)"</em>.</p>
#
# <p> 📒 &nbsp; For more help, please see the <em>"Appendix – Tips, Help, and Download"</em> Lesson.</p>
#
# </div>

# %% [markdown]
# <p style="background-color:#f7fff8; padding:15px; border-width:3px; border-color:#e0f0e0; border-style:solid; border-radius:6px"> 🚨
# &nbsp; <b>Different Run Results:</b> The output generated by AI chat models can vary with each execution due to their dynamic, probabilistic nature. Don't be surprised if your results differ from those shown in the video.</p>

# %% [markdown]
# First start by filtering warnings and loading environment variables.

# %%
# Warning control
import warnings
warnings.filterwarnings('ignore')

# %%
from helper import load_env
load_env()

# %%
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: e2b-code-interpreter==2.2.0 in c:\users\wwwdo\desktop\building coding agents using tool execution\.venv\lib\site-packages (from -r requirements.txt (line 1)) (2.2.0)
# Requirement already satisfied: gradio>=5.49.0 in c:\users\wwwdo\desktop\building coding agents using tool execution\.venv\lib\site-packages (from -r requirements.txt (line 2)) (5.50.0)
# Requirement already satisfied: notebook>=7.4.4 in c:\users\wwwdo\desktop\building coding agents using tool execution\.venv\lib\site-packages (from -r requirements.txt (line 3)) (7.5.0)
# Requirement already satisfied: openai==2.4.0 in c:\users\wwwdo\desktop\building coding agents using tool execution\.venv\lib\site-packages (from -r requirements.txt (line 4)) (2.4.0)
# Requirement already satisfied: pillow>=11.3.0 in c:\users\wwwdo\desktop\building coding agents using tool execution\.venv\lib\site-packages (from -r requirements.txt (line 5)) (11.3.0)
# Requirement already satisfied: python-dotenv>=1.1.1 in c:\users\wwwdo\desktop\building coding agents using tool execution\.venv\lib\site-packages (from -r requirements.txt (line 6)) (1.2.1)
# Requirement already satisfied: rich>=14.1.0 in c:\users\wwwdo\desktop\building coding agents using tool execution\.venv\lib\site-packages (from -r requirements.txt (line 7)) (14.2.0)
# Requirement already satisfied: tiktoken>=0.9.0 in c:\users\wwwdo\desktop\building coding agents using tool execution\.venv\lib\site-packages (from -r requirements.txt (line 8)) (0.12.0)
# Requirement already satisfied: gradio-browser==0.0.3 in c:\users\wwwdo\desktop\building coding agents using tool execution\.venv\lib\site-packages (from -r requirements.txt (line 9)) (0.0.3)
# Requirement already satisfied: gradio-aicontext==0.0.4 in c:\users\wwwdo\desktop\building coding agents using tool execution\.venv\lib\site-packages (from -r requirements.txt (line 10)) (0.0.4)
# Requirement already satisfied: attrs>=21.3.0 in c:\users\wwwdo\desktop\building coding agents using tool execution\.venv\lib\site-packages (from e2b-code-interpreter==2.2.0->-r requirements.txt (line 1)) (25.4.0)
# Requirement already satisfied: e2b<3.0.0,>=2.3.0 in c:\users\wwwdo\desktop\building coding agents using tool execution\.venv\lib\site-packages (from e2b-code-interpreter==2.2.0->-r requirements.txt (line 1)) (2.8.1)
# Requirement already satisfied: httpx<1.0.0,>=0.20.0 in c:\users\wwwdo\desktop\building coding agents using tool execution\.venv\lib\site-packages (from e2b-code-interpreter==2.2.0->-r requirements.txt (line 1)) (0.28.1)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\wwwdo\desktop\building coding agents using tool execution\.venv\lib\site-packages (from openai==2.4.0->-r requirements.txt (line 4)) (4.12.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\wwwdo\desktop\building coding agents using tool execution\.venv\lib\site-packages (from openai==2.4.0->-r requirements.txt (line 4)) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in c:\users\wwwdo\desktop\building coding agents using tool execution\.venv\lib\site-packages (from openai==2.4.0->-r requirements.txt (line 4)) (0.12.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in c:\users\wwwdo\desktop\building coding agents using tool execution\.venv\lib\site-packages (from openai==2.4.0->-r requirements.txt (line 4)) (2.12.3)
# Requirement already satisfied: sniffio in c:\users\wwwdo\desktop\building coding agents using tool execution\.venv\lib\site-packages (from openai==2.4.0->-r requirements.txt (line 4)) (1.3.1)
# Requirement already satisfied: tqdm>4 in c:\users\wwwdo\desktop\building coding agents using tool execution\.venv\lib\site-packages (from openai==2.4.0->-r requirements.txt (line 4)) (4.67.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in c:\users\wwwdo\desktop\building coding agents using tool execution\.venv\lib\site-packages (from openai==2.4.0->-r requirements.txt (line 4)) (4.15.0)
# Requirement already satisfied: aiofiles<25.0,>=22.0 in c:\users\wwwdo\desktop\building coding agents using tool execution\.venv\lib\site-packages (from gradio>=5.49.0->-r requirements.txt (line 2)) (24.1.0)
# Requirement already satisfied: brotli>=1.1.0 in c:\users\wwwdo\desktop\building coding agents using tool execution\.venv\lib\site-packages (from gradio>=5.49.0->-r requirements.txt (line 2)) (1.2.0)
# Requirement already satisfied: fastapi<1.0,>=0.115.2 in c:\users\wwwdo\desktop\building coding agents using tool execution\.venv\lib\site-packages (from gradio>=5.49.0->-r requirements.txt (line 2)) (0.123.8)
# Requirement already satisfied: ffmpy in c:\users\wwwdo\desktop\building coding agents using tool execution\.venv\lib\site-packages (from gradio>=5.49.0->-r requirements.txt (line 2)) (1.0.0)
# Requirement already satisfied: gradio-client==1.14.0 in c:\users\wwwdo\desktop\building coding agents using tool execution\.venv\lib\site-packages (from gradio>=5.49.0->-r requirements.txt (line 2)) (1.14.0)
# Requirement already satisfied: groovy~=0.1 in c:\users\wwwdo\desktop\building coding agents using tool execution\.venv\lib\site-packages (from gradio>=5.49.0->-r requirements.txt (line 2)) (0.1.2)
# Requirement already satisfied: huggingface-hub<2.0,>=0.33.5 in c:\users\wwwdo\desktop\building coding agents using tool execution\.venv\lib\site-packages (from gradio>=5.49.0->-r requirements.txt (line 2)) (1.1.7)
# Requirement already satisfied: jinja2<4.0 in c:\users\wwwdo\desktop\building coding agents using tool execution\.venv\lib\site-packages (from gradio>=5.49.0->-r requirements.txt (line 2)) (3.1.6)
# Requirement already satisfied: markupsafe<4.0,>=2.0 in c:\users\wwwdo\desktop\building coding agents using tool execution\.venv\lib\site-packages (from gradio>=5.49.0->-r requirements.txt (line 2)) (3.0.3)
# Requirement already satisfied: numpy<3.0,>=1.0 in c:\users\wwwdo\desktop\building coding agents using tool execution\.venv\lib\site-packages (from gradio>=5.49.0->-r requirements.txt (line 2)) (2.2.6)
# Requirement already satisfied: orjson~=3.0 in c:\users\wwwdo\desktop\building coding agents using tool execution\.venv\lib\site-packages (from gradio>=5.49.0->-r requirements.txt (line 2)) (3.11.4)
# Requirement already satisfied: packaging in c:\users\wwwdo\desktop\building coding agents using tool execution\.venv\lib\site-packages (from gradio>=5.49.0->-r requirements.txt (line 2)) (25.0)
# Requirement already satisfied: pandas<3.0,>=1.0 in c:\users\wwwdo\desktop\building coding agents using tool execution\.venv\lib\site-packages (from gradio>=5.49.0->-r requirements.txt (line 2)) (2.3.3)
# Requirement already satisfied: pydub in c:\users\wwwdo\desktop\building coding agents using tool execution\.venv\lib\site-packages (from gradio>=5.49.0->-r requirements.txt (line 2)) (0.25.1)
# Requirement already satisfied: python-multipart>=0.0.18 in c:\users\wwwdo\desktop\building coding agents using tool execution\.venv\lib\site-packages (from gradio>=5.49.0->-r requirements.txt (line 2)) (0.0.20)
# Requirement already satisfied: pyyaml<7.0,>=5.0 in c:\users\wwwdo\desktop\building coding agents using tool execution\.venv\lib\site-packages (from gradio>=5.49.0->-r requirements.txt (line 2)) (6.0.3)
# Requirement already satisfied: ruff>=0.9.3 in c:\users\wwwdo\desktop\building coding agents using tool execution\.venv\lib\site-packages (from gradio>=5.49.0->-r requirements.txt (line 2)) (0.14.8)
# Requirement already satisfied: safehttpx<0.2.0,>=0.1.6 in c:\users\wwwdo\desktop\building coding agents using tool execution\.venv\lib\site-packages (from gradio>=5.49.0->-r requirements.txt (line 2)) (0.1.7)
# Requirement already satisfied: semantic-version~=2.0 in c:\users\wwwdo\desktop\building coding agents using tool execution\.venv\lib\site-packages (from gradio>=5.49.0->-r requirements.txt (line 2)) (2.10.0)
# Requirement already satisfied: starlette<1.0,>=0.40.0 in c:\users\wwwdo\desktop\building coding agents using tool execution\.venv\lib\site-packages (from gradio>=5.49.0->-r requirements.txt (line 2)) (0.50.0)
# Requirement already satisfied: tomlkit<0.14.0,>=0.12.0 in c:\users\wwwdo\desktop\building coding agents using tool execution\.venv\lib\site-packages (from gradio>=5.49.0->-r requirements.txt (line 2)) (0.13.3)
# Requirement already satisfied: typer<1.0,>=0.12 in c:\users\wwwdo\desktop\building coding agents using tool execution\.venv\lib\site-packages (from gradio>=5.49.0->-r requirements.txt (line 2)) (0.20.0)
# Requirement already satisfied: uvicorn>=0.14.0 in c:\users\wwwdo\desktop\building coding agents using tool execution\.venv\lib\site-packages (from gradio>=5.49.0->-r requirements.txt (line 2)) (0.38.0)
# Requirement already satisfied: fsspec in c:\users\wwwdo\desktop\building coding agents using tool execution\.venv\lib\site-packages (from gradio-client==1.14.0->gradio>=5.49.0->-r requirements.txt (line 2)) (2025.12.0)
# Requirement already satisfied: websockets<16.0,>=13.0 in c:\users\wwwdo\desktop\building coding agents using tool execution\.venv\lib\site-packages (from gradio-client==1.14.0->gradio>=5.49.0->-r requirements.txt (line 2)) (15.0.1)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\wwwdo\desktop\building coding agents using tool execution\.venv\lib\site-packages (from anyio<5,>=3.5.0->openai==2.4.0->-r requirements.txt (line 4)) (1.3.1)
# Requirement already satisfied: idna>=2.8 in c:\users\wwwdo\desktop\building coding agents using tool execution\.venv\lib\site-packages (from anyio<5,>=3.5.0->openai==2.4.0->-r requirements.txt (line 4)) (3.11)
# Requirement already satisfied: dockerfile-parse<3.0.0,>=2.0.1 in c:\users\wwwdo\desktop\building coding agents using tool execution\.venv\lib\site-packages (from e2b<3.0.0,>=2.3.0->e2b-code-interpreter==2.2.0->-r requirements.txt (line 1)) (2.0.1)
# Requirement already satisfied: httpcore<2.0.0,>=1.0.5 in c:\users\wwwdo\desktop\building coding agents using tool execution\.venv\lib\site-packages (from e2b<3.0.0,>=2.3.0->e2b-code-interpreter==2.2.0->-r requirements.txt (line 1)) (1.0.9)
# Requirement already satisfied: protobuf>=4.21.0 in c:\users\wwwdo\desktop\building coding agents using tool execution\.venv\lib\site-packages (from e2b<3.0.0,>=2.3.0->e2b-code-interpreter==2.2.0->-r requirements.txt (line 1)) (6.33.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\wwwdo\desktop\building coding agents using tool execution\.venv\lib\site-packages (from e2b<3.0.0,>=2.3.0->e2b-code-interpreter==2.2.0->-r requirements.txt (line 1)) (2.9.0.post0)
# Requirement already satisfied: wcmatch<11.0,>=10.1 in c:\users\wwwdo\desktop\building coding agents using tool execution\.venv\lib\site-packages (from e2b<3.0.0,>=2.3.0->e2b-code-interpreter==2.2.0->-r requirements.txt (line 1)) (10.1)
# Requirement already satisfied: annotated-doc>=0.0.2 in c:\users\wwwdo\desktop\building coding agents using tool execution\.venv\lib\site-packages (from fastapi<1.0,>=0.115.2->gradio>=5.49.0->-r requirements.txt (line 2)) (0.0.4)
# Requirement already satisfied: certifi in c:\users\wwwdo\desktop\building coding agents using tool execution\.venv\lib\site-packages (from httpcore<2.0.0,>=1.0.5->e2b<3.0.0,>=2.3.0->e2b-code-interpreter==2.2.0->-r requirements.txt (line 1)) (2025.11.12)
# Requirement already satisfied: h11>=0.16 in c:\users\wwwdo\desktop\building coding agents using tool execution\.venv\lib\site-packages (from httpcore<2.0.0,>=1.0.5->e2b<3.0.0,>=2.3.0->e2b-code-interpreter==2.2.0->-r requirements.txt (line 1)) (0.16.0)
# Requirement already satisfied: filelock in c:\users\wwwdo\desktop\building coding agents using tool execution\.venv\lib\site-packages (from huggingface-hub<2.0,>=0.33.5->gradio>=5.49.0->-r requirements.txt (line 2)) (3.20.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.2.0 in c:\users\wwwdo\desktop\building coding agents using tool execution\.venv\lib\site-packages (from huggingface-hub<2.0,>=0.33.5->gradio>=5.49.0->-r requirements.txt (line 2)) (1.2.0)
# Requirement already satisfied: shellingham in c:\users\wwwdo\desktop\building coding agents using tool execution\.venv\lib\site-packages (from huggingface-hub<2.0,>=0.33.5->gradio>=5.49.0->-r requirements.txt (line 2)) (1.5.4)
# Requirement already satisfied: typer-slim in c:\users\wwwdo\desktop\building coding agents using tool execution\.venv\lib\site-packages (from huggingface-hub<2.0,>=0.33.5->gradio>=5.49.0->-r requirements.txt (line 2)) (0.20.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\wwwdo\desktop\building coding agents using tool execution\.venv\lib\site-packages (from pandas<3.0,>=1.0->gradio>=5.49.0->-r requirements.txt (line 2)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\wwwdo\desktop\building coding agents using tool execution\.venv\lib\site-packages (from pandas<3.0,>=1.0->gradio>=5.49.0->-r requirements.txt (line 2)) (2025.2)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\wwwdo\desktop\building coding agents using tool execution\.venv\lib\site-packages (from pydantic<3,>=1.9.0->openai==2.4.0->-r requirements.txt (line 4)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in c:\users\wwwdo\desktop\building coding agents using tool execution\.venv\lib\site-packages (from pydantic<3,>=1.9.0->openai==2.4.0->-r requirements.txt (line 4)) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\wwwdo\desktop\building coding agents using tool execution\.venv\lib\site-packages (from pydantic<3,>=1.9.0->openai==2.4.0->-r requirements.txt (line 4)) (0.4.2)
# Requirement already satisfied: click>=8.0.0 in c:\users\wwwdo\desktop\building coding agents using tool execution\.venv\lib\site-packages (from typer<1.0,>=0.12->gradio>=5.49.0->-r requirements.txt (line 2)) (8.3.1)
# Requirement already satisfied: bracex>=2.1.1 in c:\users\wwwdo\desktop\building coding agents using tool execution\.venv\lib\site-packages (from wcmatch<11.0,>=10.1->e2b<3.0.0,>=2.3.0->e2b-code-interpreter==2.2.0->-r requirements.txt (line 1)) (2.6)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in c:\users\wwwdo\desktop\building coding agents using tool execution\.venv\lib\site-packages (from notebook>=7.4.4->-r requirements.txt (line 3)) (2.17.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.28.0 in c:\users\wwwdo\desktop\building coding agents using tool execution\.venv\lib\site-packages (from notebook>=7.4.4->-r requirements.txt (line 3)) (2.28.0)
# Requirement already satisfied: jupyterlab<4.6,>=4.5.0rc0 in c:\users\wwwdo\desktop\building coding agents using tool execution\.venv\lib\site-packages (from notebook>=7.4.4->-r requirements.txt (line 3)) (4.5.0)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in c:\users\wwwdo\desktop\building coding agents using tool execution\.venv\lib\site-packages (from notebook>=7.4.4->-r requirements.txt (line 3)) (0.2.4)
# Requirement already satisfied: tornado>=6.2.0 in c:\users\wwwdo\desktop\building coding agents using tool execution\.venv\lib\site-packages (from notebook>=7.4.4->-r requirements.txt (line 3)) (6.5.2)
# Requirement already satisfied: argon2-cffi>=21.1 in c:\users\wwwdo\desktop\building coding agents using tool execution\.venv\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=7.4.4->-r requirements.txt (line 3)) (25.1.0)
# Requirement already satisfied: jupyter-client>=7.4.4 in c:\users\wwwdo\desktop\building coding agents using tool execution\.venv\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=7.4.4->-r requirements.txt (line 3)) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\wwwdo\desktop\building coding agents using tool execution\.venv\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=7.4.4->-r requirements.txt (line 3)) (5.9.1)
# Requirement already satisfied: jupyter-events>=0.11.0 in c:\users\wwwdo\desktop\building coding agents using tool execution\.venv\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=7.4.4->-r requirements.txt (line 3)) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in c:\users\wwwdo\desktop\building coding agents using tool execution\.venv\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=7.4.4->-r requirements.txt (line 3)) (0.5.3)
# Requirement already satisfied: nbconvert>=6.4.4 in c:\users\wwwdo\desktop\building coding agents using tool execution\.venv\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=7.4.4->-r requirements.txt (line 3)) (7.16.6)
# Requirement already satisfied: nbformat>=5.3.0 in c:\users\wwwdo\desktop\building coding agents using tool execution\.venv\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=7.4.4->-r requirements.txt (line 3)) (5.10.4)
# Requirement already satisfied: overrides>=5.0 in c:\users\wwwdo\desktop\building coding agents using tool execution\.venv\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=7.4.4->-r requirements.txt (line 3)) (7.7.0)
# Requirement already satisfied: prometheus-client>=0.9 in c:\users\wwwdo\desktop\building coding agents using tool execution\.venv\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=7.4.4->-r requirements.txt (line 3)) (0.23.1)
# Requirement already satisfied: pywinpty>=2.0.1 in c:\users\wwwdo\desktop\building coding agents using tool execution\.venv\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=7.4.4->-r requirements.txt (line 3)) (3.0.2)
# Requirement already satisfied: pyzmq>=24 in c:\users\wwwdo\desktop\building coding agents using tool execution\.venv\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=7.4.4->-r requirements.txt (line 3)) (27.1.0)
# Requirement already satisfied: send2trash>=1.8.2 in c:\users\wwwdo\desktop\building coding agents using tool execution\.venv\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=7.4.4->-r requirements.txt (line 3)) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\wwwdo\desktop\building coding agents using tool execution\.venv\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=7.4.4->-r requirements.txt (line 3)) (0.18.1)
# Requirement already satisfied: traitlets>=5.6.0 in c:\users\wwwdo\desktop\building coding agents using tool execution\.venv\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=7.4.4->-r requirements.txt (line 3)) (5.14.3)
# Requirement already satisfied: websocket-client>=1.7 in c:\users\wwwdo\desktop\building coding agents using tool execution\.venv\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=7.4.4->-r requirements.txt (line 3)) (1.9.0)
# Requirement already satisfied: async-lru>=1.0.0 in c:\users\wwwdo\desktop\building coding agents using tool execution\.venv\lib\site-packages (from jupyterlab<4.6,>=4.5.0rc0->notebook>=7.4.4->-r requirements.txt (line 3)) (2.0.5)
# Requirement already satisfied: ipykernel!=6.30.0,>=6.5.0 in c:\users\wwwdo\desktop\building coding agents using tool execution\.venv\lib\site-packages (from jupyterlab<4.6,>=4.5.0rc0->notebook>=7.4.4->-r requirements.txt (line 3)) (7.1.0)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in c:\users\wwwdo\desktop\building coding agents using tool execution\.venv\lib\site-packages (from jupyterlab<4.6,>=4.5.0rc0->notebook>=7.4.4->-r requirements.txt (line 3)) (2.3.0)
# Requirement already satisfied: setuptools>=41.1.0 in c:\users\wwwdo\desktop\building coding agents using tool execution\.venv\lib\site-packages (from jupyterlab<4.6,>=4.5.0rc0->notebook>=7.4.4->-r requirements.txt (line 3)) (58.1.0)
# Requirement already satisfied: tomli>=1.2.2 in c:\users\wwwdo\desktop\building coding agents using tool execution\.venv\lib\site-packages (from jupyterlab<4.6,>=4.5.0rc0->notebook>=7.4.4->-r requirements.txt (line 3)) (2.3.0)
# Requirement already satisfied: babel>=2.10 in c:\users\wwwdo\desktop\building coding agents using tool execution\.venv\lib\site-packages (from jupyterlab-server<3,>=2.28.0->notebook>=7.4.4->-r requirements.txt (line 3)) (2.17.0)
# Requirement already satisfied: json5>=0.9.0 in c:\users\wwwdo\desktop\building coding agents using tool execution\.venv\lib\site-packages (from jupyterlab-server<3,>=2.28.0->notebook>=7.4.4->-r requirements.txt (line 3)) (0.12.1)
# Requirement already satisfied: jsonschema>=4.18.0 in c:\users\wwwdo\desktop\building coding agents using tool execution\.venv\lib\site-packages (from jupyterlab-server<3,>=2.28.0->notebook>=7.4.4->-r requirements.txt (line 3)) (4.25.1)
# Requirement already satisfied: requests>=2.31 in c:\users\wwwdo\desktop\building coding agents using tool execution\.venv\lib\site-packages (from jupyterlab-server<3,>=2.28.0->notebook>=7.4.4->-r requirements.txt (line 3)) (2.32.5)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\wwwdo\desktop\building coding agents using tool execution\.venv\lib\site-packages (from rich>=14.1.0->-r requirements.txt (line 7)) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\wwwdo\desktop\building coding agents using tool execution\.venv\lib\site-packages (from rich>=14.1.0->-r requirements.txt (line 7)) (2.19.2)
# Requirement already satisfied: regex>=2022.1.18 in c:\users\wwwdo\desktop\building coding agents using tool execution\.venv\lib\site-packages (from tiktoken>=0.9.0->-r requirements.txt (line 8)) (2025.11.3)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\wwwdo\desktop\building coding agents using tool execution\.venv\lib\site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook>=7.4.4->-r requirements.txt (line 3)) (25.1.0)
# Requirement already satisfied: colorama in c:\users\wwwdo\desktop\building coding agents using tool execution\.venv\lib\site-packages (from click>=8.0.0->typer<1.0,>=0.12->gradio>=5.49.0->-r requirements.txt (line 2)) (0.4.6)
# Requirement already satisfied: comm>=0.1.1 in c:\users\wwwdo\desktop\building coding agents using tool execution\.venv\lib\site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.6,>=4.5.0rc0->notebook>=7.4.4->-r requirements.txt (line 3)) (0.2.3)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\wwwdo\desktop\building coding agents using tool execution\.venv\lib\site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.6,>=4.5.0rc0->notebook>=7.4.4->-r requirements.txt (line 3)) (1.8.17)
# Requirement already satisfied: ipython>=7.23.1 in c:\users\wwwdo\desktop\building coding agents using tool execution\.venv\lib\site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.6,>=4.5.0rc0->notebook>=7.4.4->-r requirements.txt (line 3)) (8.37.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\wwwdo\desktop\building coding agents using tool execution\.venv\lib\site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.6,>=4.5.0rc0->notebook>=7.4.4->-r requirements.txt (line 3)) (0.2.1)
# Requirement already satisfied: nest-asyncio>=1.4 in c:\users\wwwdo\desktop\building coding agents using tool execution\.venv\lib\site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.6,>=4.5.0rc0->notebook>=7.4.4->-r requirements.txt (line 3)) (1.6.0)
# Requirement already satisfied: psutil>=5.7 in c:\users\wwwdo\desktop\building coding agents using tool execution\.venv\lib\site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.6,>=4.5.0rc0->notebook>=7.4.4->-r requirements.txt (line 3)) (7.1.3)
# Requirement already satisfied: decorator in c:\users\wwwdo\desktop\building coding agents using tool execution\.venv\lib\site-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.6,>=4.5.0rc0->notebook>=7.4.4->-r requirements.txt (line 3)) (5.2.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\wwwdo\desktop\building coding agents using tool execution\.venv\lib\site-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.6,>=4.5.0rc0->notebook>=7.4.4->-r requirements.txt (line 3)) (0.19.2)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\wwwdo\desktop\building coding agents using tool execution\.venv\lib\site-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.6,>=4.5.0rc0->notebook>=7.4.4->-r requirements.txt (line 3)) (3.0.52)
# Requirement already satisfied: stack_data in c:\users\wwwdo\desktop\building coding agents using tool execution\.venv\lib\site-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.6,>=4.5.0rc0->notebook>=7.4.4->-r requirements.txt (line 3)) (0.6.3)
# Requirement already satisfied: wcwidth in c:\users\wwwdo\desktop\building coding agents using tool execution\.venv\lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.6,>=4.5.0rc0->notebook>=7.4.4->-r requirements.txt (line 3)) (0.2.14)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\wwwdo\desktop\building coding agents using tool execution\.venv\lib\site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.6,>=4.5.0rc0->notebook>=7.4.4->-r requirements.txt (line 3)) (0.8.5)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\wwwdo\desktop\building coding agents using tool execution\.venv\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->notebook>=7.4.4->-r requirements.txt (line 3)) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\wwwdo\desktop\building coding agents using tool execution\.venv\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->notebook>=7.4.4->-r requirements.txt (line 3)) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\wwwdo\desktop\building coding agents using tool execution\.venv\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->notebook>=7.4.4->-r requirements.txt (line 3)) (0.30.0)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\wwwdo\desktop\building coding agents using tool execution\.venv\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-server<3,>=2.4.0->notebook>=7.4.4->-r requirements.txt (line 3)) (4.5.0)
# Requirement already satisfied: python-json-logger>=2.0.4 in c:\users\wwwdo\desktop\building coding agents using tool execution\.venv\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=7.4.4->-r requirements.txt (line 3)) (4.0.0)
# Requirement already satisfied: rfc3339-validator in c:\users\wwwdo\desktop\building coding agents using tool execution\.venv\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=7.4.4->-r requirements.txt (line 3)) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in c:\users\wwwdo\desktop\building coding agents using tool execution\.venv\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=7.4.4->-r requirements.txt (line 3)) (0.1.1)
# Requirement already satisfied: fqdn in c:\users\wwwdo\desktop\building coding agents using tool execution\.venv\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=7.4.4->-r requirements.txt (line 3)) (1.5.1)
# Requirement already satisfied: isoduration in c:\users\wwwdo\desktop\building coding agents using tool execution\.venv\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=7.4.4->-r requirements.txt (line 3)) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in c:\users\wwwdo\desktop\building coding agents using tool execution\.venv\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=7.4.4->-r requirements.txt (line 3)) (3.0.0)
# Requirement already satisfied: rfc3987-syntax>=1.1.0 in c:\users\wwwdo\desktop\building coding agents using tool execution\.venv\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=7.4.4->-r requirements.txt (line 3)) (1.1.0)
# Requirement already satisfied: uri-template in c:\users\wwwdo\desktop\building coding agents using tool execution\.venv\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=7.4.4->-r requirements.txt (line 3)) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in c:\users\wwwdo\desktop\building coding agents using tool execution\.venv\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=7.4.4->-r requirements.txt (line 3)) (25.10.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\wwwdo\desktop\building coding agents using tool execution\.venv\lib\site-packages (from markdown-it-py>=2.2.0->rich>=14.1.0->-r requirements.txt (line 7)) (0.1.2)
# Requirement already satisfied: beautifulsoup4 in c:\users\wwwdo\desktop\building coding agents using tool execution\.venv\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=7.4.4->-r requirements.txt (line 3)) (4.14.3)
# Requirement already satisfied: bleach!=5.0.0 in c:\users\wwwdo\desktop\building coding agents using tool execution\.venv\lib\site-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=7.4.4->-r requirements.txt (line 3)) (6.3.0)
# Requirement already satisfied: defusedxml in c:\users\wwwdo\desktop\building coding agents using tool execution\.venv\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=7.4.4->-r requirements.txt (line 3)) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in c:\users\wwwdo\desktop\building coding agents using tool execution\.venv\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=7.4.4->-r requirements.txt (line 3)) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in c:\users\wwwdo\desktop\building coding agents using tool execution\.venv\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=7.4.4->-r requirements.txt (line 3)) (3.1.4)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\wwwdo\desktop\building coding agents using tool execution\.venv\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=7.4.4->-r requirements.txt (line 3)) (0.10.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\wwwdo\desktop\building coding agents using tool execution\.venv\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=7.4.4->-r requirements.txt (line 3)) (1.5.1)
# Requirement already satisfied: webencodings in c:\users\wwwdo\desktop\building coding agents using tool execution\.venv\lib\site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=7.4.4->-r requirements.txt (line 3)) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in c:\users\wwwdo\desktop\building coding agents using tool execution\.venv\lib\site-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=7.4.4->-r requirements.txt (line 3)) (1.4.0)
# Requirement already satisfied: fastjsonschema>=2.15 in c:\users\wwwdo\desktop\building coding agents using tool execution\.venv\lib\site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->notebook>=7.4.4->-r requirements.txt (line 3)) (2.21.2)
# Requirement already satisfied: six>=1.5 in c:\users\wwwdo\desktop\building coding agents using tool execution\.venv\lib\site-packages (from python-dateutil>=2.8.2->e2b<3.0.0,>=2.3.0->e2b-code-interpreter==2.2.0->-r requirements.txt (line 1)) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\wwwdo\desktop\building coding agents using tool execution\.venv\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.28.0->notebook>=7.4.4->-r requirements.txt (line 3)) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\wwwdo\desktop\building coding agents using tool execution\.venv\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.28.0->notebook>=7.4.4->-r requirements.txt (line 3)) (2.5.0)
# Requirement already satisfied: lark>=1.2.2 in c:\users\wwwdo\desktop\building coding agents using tool execution\.venv\lib\site-packages (from rfc3987-syntax>=1.1.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=7.4.4->-r requirements.txt (line 3)) (1.3.1)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\wwwdo\desktop\building coding agents using tool execution\.venv\lib\site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook>=7.4.4->-r requirements.txt (line 3)) (2.0.0)
# Requirement already satisfied: pycparser in c:\users\wwwdo\desktop\building coding agents using tool execution\.venv\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook>=7.4.4->-r requirements.txt (line 3)) (2.23)
# Requirement already satisfied: soupsieve>=1.6.1 in c:\users\wwwdo\desktop\building coding agents using tool execution\.venv\lib\site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=7.4.4->-r requirements.txt (line 3)) (2.8)
# Requirement already satisfied: arrow>=0.15.0 in c:\users\wwwdo\desktop\building coding agents using tool execution\.venv\lib\site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=7.4.4->-r requirements.txt (line 3)) (1.4.0)
# Requirement already satisfied: executing>=1.2.0 in c:\users\wwwdo\desktop\building coding agents using tool execution\.venv\lib\site-packages (from stack_data->ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.6,>=4.5.0rc0->notebook>=7.4.4->-r requirements.txt (line 3)) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\wwwdo\desktop\building coding agents using tool execution\.venv\lib\site-packages (from stack_data->ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.6,>=4.5.0rc0->notebook>=7.4.4->-r requirements.txt (line 3)) (3.0.1)
# Requirement already satisfied: pure-eval in c:\users\wwwdo\desktop\building coding agents using tool execution\.venv\lib\site-packages (from stack_data->ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.6,>=4.5.0rc0->notebook>=7.4.4->-r requirements.txt (line 3)) (0.2.3)

# %% [markdown]
# Now, let's create the data analyst agent. You will create a sandbox, then open the `pokemon.csv` dataset and write it to the sandbox as `data.csv`.

# %%
from lib.utils import create_sandbox

sbx = create_sandbox()

with open("pokemon.csv", "r", encoding="utf-8") as f:
    content = f.read()

sbx.files.write("data.csv", content)
# Out:
# INFO     [sandbox] 🔌 Reconnecting to Sandbox.create(id=iqld77v55jrw0byr0fyvq)
# WriteInfo(name='data.csv', type='file', path='/home/user/data.csv')

# %% [markdown]
# Now you can import your `coding_agent` and modify the system prompt to let it know that the user has uploaded a dataset called `data.csv` and it should create interesting plots.

# %%
from lib.coding_agent import coding_agent, log
from lib.tools_schemas import execute_code_schema
from lib.tools import execute_code
from openai import OpenAI

client = OpenAI()

system = """You are a senior python programmer. 
You must run the code using the `execute_code` tool.
The user has uploaded a data.csv.
You help the user understanding the data 
by creating interesting plots.
"""

tools = { "execute_code" : execute_code }

# %% [markdown]
# Now you can query the data as normal and the sandbox will execute code on the data to answer the queries.

# %%
messages = []

query = "What is the data about?"

messages, usage = log(coding_agent,
    messages=messages,
    query=query,
    client=client,
    system=system,
    tools_schemas=[execute_code_schema],
    tools=tools,
    max_steps=10,
    sbx=sbx,
)
# Out:
# ╭───────────────────────────────────────────────── 🤖 Tool Call ──────────────────────────────────────────────────╮
# │ execute_code                                                                                                    │
# │ Arguments: {"code":"import pandas as pd\n\ndf = pd.read_csv('data.csv')\ndf.head(), df.columns.tolist(),        │
# │ df.info()"}                                                                                                     │
# │ Result: {"results": [{"text": "(                     abilities  against_bug  against_dark  against_dragon  \\\n │
# │ 0  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0   \n 1  ['Overgrow', '...             │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# INFO     ✨: The data appears to be about Pokémon. It contains several columns related to each Pokémon's
#          attributes, including:
#
#          - Abilities
#          - Effectiveness against different types (e.g., bug, dark, dragon)
#          - Base stats such as attack, defense, hp, sp_attack, sp_defense, and speed
#          - Other characteristics like height, weight, generation, and whether they are legendary
#          - Additional information such as name, type(s), classification, capture rate, and percentage male
#
#          There are 801 entries (Pokémon) and 41 columns with various data types.
#
#          Would you like me to generate some visualizations to help better understand the distribution or
#          relationships in this data?
# INFO     [agent] 🔢 tokens: 2094 total

# %%
query = "Can you aggregate the pokemons by type?"

messages, usage = log(coding_agent,
    messages=messages,
    query=query,
    client=client,
    system=system,
    tools_schemas=[execute_code_schema],
    tools=tools,
    max_steps=10,
    sbx=sbx,
)
# Out:
# ╭───────────────────────────────────────────────── 🤖 Tool Call ──────────────────────────────────────────────────╮
# │ execute_code                                                                                                    │
# │ Arguments: {"code":"type1_counts = df['type1'].value_counts()\ntype2_counts =                                   │
# │ df['type2'].value_counts()\ntype1_counts, type2_counts"}                                                        │
# │ Result: {"results": [{"text": "(type1\n water       114\n normal      105\n grass        78\n bug          72\n │
# │ psychic      53\n fire         52\n rock         45\n electric     39\n poison       32\n ground...             │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# INFO     ✨: Here is the aggregation of Pokémon by their primary (type1) and secondary (type2) types:
#
#          Primary Type (type1) counts:
#          - Water: 114
#          - Normal: 105
#          - Grass: 78
#          - Bug: 72
#          - Psychic: 53
#          - Fire: 52
#          - Rock: 45
#          - Electric: 39
#          - Poison: 32
#          - Ground: 32
#          - Dark: 29
#          - Fighting: 28
#          - Dragon: 27
#          - Ghost: 27
#          - Steel: 24
#          - Ice: 23
#          - Fairy: 18
#          - Flying: 3
#
#          Secondary Type (type2) counts:
#          - Flying: 95
#          - Poison: 34
#          - Ground: 34
#          - Fairy: 29
#          - Psychic: 29
#          - Fighting: 25
#          - Steel: 22
#          - Dark: 21
#          - Grass: 20
#          - Water: 17
#          - Dragon: 17
#          - Ice: 15
#          - Ghost: 14
#          - Rock: 14
#          - Fire: 13
#          - Electric: 9
#          - Bug: 5
#          - Normal: 4
#
#          Would you like to see these counts in a plot for easier comparison?
# INFO     [agent] 🔢 tokens: 2713 total

# %% [markdown]
# ### Gradio UI
#
# You can use this provided Gradio UI to have a nicer user experience when chatting with your code generation agent. It will also give interesting information about the context stack, including the number of tokens used in the result, by the assistant, the user, and tools.

# %%
from lib.ui import ui

ui(coding_agent,
    messages,
    client=client,
    system=system,
    tools_schemas=[execute_code_schema],
    tools=tools,
    max_steps=10,
    sbx=sbx,
).launch(share=True, height=800)
# Out:
# * Running on local URL:  http://127.0.0.1:7860
# * Running on public URL: https://12e21538838e064975.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# * Running on public URL: https://12e21538838e064975.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://12e21538838e064975.gradio.live" width="100%" height="800" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %% [markdown]
# ## Your Turn
#
# Now it's your turn to explore this unknown dataset. Ask questions and learn more about the information inside.

# %%
# sbx = create_sandbox()
# with open("unknown.csv", "r", encoding="utf-8") as f:
#     content = f.read()
# sbx.files.write("data.csv", content)

# messages = []

# ui(
#     coding_agent,
#     messages,
#     client=client,
#     system=system,
#     tools_schemas=[execute_code_schema],
#     tools=tools,
#     max_steps=10,
#     sbx=sbx,
# ).launch(share=True, height=800)
